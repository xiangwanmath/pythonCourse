# %% [markdown]
# ## Examples for September 5, 2023

# %% [markdown]
# Format strings

# %%
import math
print(f'{math.pi:.2f}')
print(f'{math.pi:.25f}')
# Out:
# 3.14
# 3.1415926535897931159979635

# %% [markdown]
# Boolean Expressions

# %%
'dog'=='Dog'
# Out:
# False

# %%
math.pi == 3.14159265
# Out:
# False

# %%
round(math.pi, 5) == round(3.14159265, 5)
# Out:
# True

# %%
age = 12   # try 'newborn'
if age > 7:
  print('old enough')
else:
  print('too young')
# Out:
# old enough

# %% [markdown]
# Test if an integer is even or odd

# %%
x = 17
if x % 2 == 0:
  print("even")
else:
  print('odd')
# Out:
# odd

# %%
phoneNumber = int('7735083591')   #input("Enter a 10 digit phone number with no other symbols"))
areaCode = int(phoneNumber//1e7)
print("Area code: ", areaCode)

sevenDigits = phoneNumber%10000000
#print(sevenDigits)

prefix = sevenDigits//10000
print('Prefix: ', prefix)

fourDigits = sevenDigits%10000
print('Last four digits: ', fourDigits)

# %% [markdown]
# What could go wrong?  773 274 0003
#
# Correct this using if-else

# %% [markdown]
# Solution using strings

# %%
phoneNumber = '7735083591'   #input("Enter a 10 digit phone number with no other symbols"))
areaCode = phoneNumber[0:3]
print("Area code: ", areaCode)

prefix = phoneNumber[3:6]
print('Prefix: ', prefix)

fourDigits = phoneNumber[6:11]
print('Last four digits: ', fourDigits)

# %%
letter = '-5'
print('A' <= letter <= 'Z')
print(letter.isdigit())
# Out:
# False
# False

# %%
import math
d = 7.5
if d > 0:
  print(f'The square root of {d} is {math.sqrt(d)}')
else:
  print(f'{d} is not positive')
# Out:
# The square root of 7.5 is 2.7386127875258306
