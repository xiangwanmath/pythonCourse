# %% [markdown]
# Use a for-loop to sum a series

# %%
# Geometric series with r = 1/2 converges fast to 2
num_terms = 200
running_sum = 0
for n in range(num_terms):
  next_term = 1/2**n
  running_sum += next_term

print(f'The sum is {running_sum} using {num_terms} terms')
# Out:
# The sum is 2.0 using 200 terms

# %%
# Alternating harmonic series, converges slowly to ln(2)
num_terms = 200000
running_sum = 0
for n in range(1, num_terms):
  next_term = (-1)**(n-1) / n
  running_sum += next_term

print(f'The sum is {running_sum} using {num_terms} terms')
# Out:
# The sum is 0.6931496805662333 using 200000 terms

# %% [markdown]
# Substitution Cipher Program Outline

# %%
# Caesar Cipher program for Math 215 Sept 14, 2023

charSet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# Prompt user and read in an integer shift value, n.




# Prompt user and read in the text to be encoded, store
# this in a variable called plaintext

plaintext = 'CaT or ZEBRA'  # or read it from user

plaintext = plaintext.upper()  # Make sure it is upper case

# You can use indexing into charSet or ord and chr to convert a letter to a number
# Encode the plaintext using a caesar cipher with right shift n, creating ciphertext
ciphertext = ''
for symbol in plaintext:
  pass
  # encode symbol and append it to ciphertext


# Display the encoded text, ciphertext



# Decode ciphertext with shift n, creating decodetext



# Display decodetext



# Test if decodetext is the same as the original plaintext.

# %%
ord('A')
# Out:
# 65

# %%
chr(90)
# Out:
# 'Z'

# %%
ord('$')
# Out:
# 36

# %%
ord('a')
# Out:
# 97

# %%
chr(12345)
# Out:
# '〹'
