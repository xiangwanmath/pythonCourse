# %% [markdown]
# Math 215 - Fall 2023 - HW3 - Due October 6, 2023 in Sakai
# 40 points

# %% [markdown]
# 1.  (9 points)  Complete the chatbot program we started in class with these additional features:
#
# A.  Use a dictionary to store the question/answer pairs.  The question string should be the key and the answer string should be the value
#
# B.  Include at least 5 questions.  Use dictionary look-up to find the question (not if-elif)
#
# C.  Make the queries insensitive to case - so any kind of capitalization in the question is ignored
#
# D.  You chatbot must correctly answer the questions it knows the answer to, must give a polite informative response when it does not know the answer and it must exit cleanly when the user_query is "i'm done".
#
# Extra Credit (5 points possible):
# Make your chatbot more intelligent.  You might allow it to search for keywords in the user_query rather than an exact match,  or you might want to allow the chatbot to bluff on queries it does not know the answer to, or you could have other ideas.  Include a text cell explaining any enhancements you add so we dont miss your intentions when grading.

# %% [markdown]
# 2.  (15 points) DNA strings and functions
#
# Using the code I provided, read in the dna sequence for ecoli.  You will need to upload the file ecoli.txt to colab.  Implement each as as a function.  I have dictated the program structure here - you may only change the code in the bodies of the functions task1, task2, task3, task4, and the calling code for task4.  There are 5 print statements that start with print("To do:  "). You should replace those print statements with your code.   (3 points for each part listed below)
#
# 2.1  Return the G-concentration in the string (= the number of G’s in the string)/(length of string).  Input: dna string.  Return value:  float
#
# 2.2  Generate a random DNA string of length n.  Input: int n, Return value: string
#
# 2.3  The location of the beginning of the substring of your DNA string of length 10 that has the highest G-concentration.  Input: dna string. Return value: int
#
# 2.4  Your Choice.  Think of a another function to implement - different from 2.1, 2.2, 2.3 and length.
#
# 2.5  Write the correct calling code for your task 4

# %%
with open('ecoli.txt', 'r') as txtfile:
  dna_str = txtfile.read()

if len(dna_str) != 4638690:
  print("problem reading from ecoli.txt")

dna_str = dna_str.upper()

def show_menu():
  print()
  print(f'Here are the possible tasks:')
  print(f'1:  Find the G-concentration of a DNA string')
  print(f'2:  Generate a random DNA string')
  print(f'3:  The location of the beginning of the substring of a DNA string')
  print(f'        of length 10 that has the highest G-concentration')
  print(f'4:  Your task')
  print(f'-1: Quit')
  print()

def get_string():
  print('Would you like to use ecoli (E) or a random string of DNA (R)? Type E or R')
  choice = input()
  if choice.upper() == 'E':
    user_str = dna_str
  else:
    user_str = task2(50)
  return user_str

def task1(astr):
  # return the G-concentration of astr
  print('To do 1:  Implement task1')
  return -1

def task2(n):
  # return a random DNA string of length n
  print('To do 2:  Implement task2')
  return ''

def task3(astr):
  # return the location of the beginning of the substring of a DNA string
  # of length 10 that has the highest G-Concnetration
  print('To do 3:  Implement task3')
  return -1

def task4():
  # Implement a task of your choosing.  Document here in a comment what your function computes
  # You may add parameters to the function as needed
  print('To do 4:  Implement task4')

user_task = 0
while user_task != -1:
  show_menu()
  user_task = int(input("Select a task by number "))
  if user_task == 1:
    str1 = get_string()
    print(f'G concentration of {str1[0:5]}... is {task1(str1):.6f}')
  elif user_task == 2:
    m = int(input('Enter the length as a positive integer: '))
    print(f'Random DNA string is {task2(m)}')
  elif user_task == 3:
    str3 = get_string()
    print(f'Location of highest G concentration of {str1[0:5]}... is index {task3(str3)}')
  elif user_task == 4:
    print("To do 5:  Write calling code for task 4")
  elif user_task == -1:
    print('Goodbye')
  else:
    print("Make a valid choice")
# Out:
# Here are the possible tasks:
# 1:  Find the G-concentration of a DNA string
# 2:  Generate a random DNA string
# 3:  The location of the beginning of the substring of a DNA string
#         of length 10 that has the highest G-concentration
# 4:  Your task
# -1: Quit
#
# Select a task by number -1
# Goodbye

# %% [markdown]
# 3.  (16 points)  Hailstone sequence.
#
# 3.1  First complete the lab exercise in the zybook on the Hailstone sequence.
#
# 3.2  Then rewrite the code for the Hailstone sequence so that it uses a function. Define a function h(n) which returns the number of elements in the Hailstone sequence starting at n (including n and 1 in the count).  For example,
#
# h(1) = 1, h(2) = 2, h(16) = 5, h(25) = 24
#
# You function should not print the sequence, only return the length of the sequence.
#
# 3.3  The point (n, h(n)) is a highwater mark for the hailstone sequence if h(n) > h(j) for all j < n.  Write a function hwm(n) that returns a list of all the pairs (m, h(m)) that are highwater marks with m<=n.  For
# example, inspecting the values of the Hailstone sequence shows us that
# (1, h(1)), (2, h(2)), (3, h(3)), (6, h(6)), (7, h(7), (9, h(9)) and (18, h(18)) are all high water marks.
#
# 3.4  Give a graphical display of the values of the hailstone sequence.  You should plot the points (n, h(n))for n less than or equal to 10,000, with the highwater marks colored in a different color.  Refer to your graphing code from the Monte Carlo simulation for hints on how to graph points in matplotlib.
#
#
# The Collatz Conjecture (http://en.wikipedia.org/wiki/Collatz_conjecture) is:
# Take any natural number n. If n is even, divide it by 2 to get n / 2, if n is odd multiply it by 3 and add 1
# to obtain 3n + 1. Repeat the process indefinitely. The conjecture is that no matter what number you start
# with, you will always eventually reach 1. (from Wikipedia)

# %%
def h(n):
  # Your code goes here - replace my stub with the correct code
  return -1

def hwm(n):
  # Your code goes here - replace my stub with the correct code
  return [(1, 1)]

for k in range(1, 20):
  print(f'h({k}) = {h(k)}, ', end = ' ')
  if k % 8 == 0:
    print()

m = int(input("Enter a positive integer m: "))
print(f'Highwater marks below {m} are {hwm(m)}')

print('Now show a graphical respresentation')
